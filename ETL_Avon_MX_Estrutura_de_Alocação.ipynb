# %%
import pandas as pd

# %%
url='/content/erro_estrutura_alocacao_avon_mx-1721132905072.csv'

# %%
df = pd.read_csv(url)
df
# Out:
#                                 person_id  level  \
# 0    -      3
# 1    -      3
# 2    -      3
# 3    -      3
# 4    -      3
# ..                                    ...    ...
# 228  -      4
# 229  -      4
# 230  -     4
# 231  -     4
# 232  -      4
#
#                                   description  external_code  \
# 0                        - de -    -.0
# 1                             SAN - -            NaN
# 2                          - de -    -.0
# 3                                  -    -.0
# 4                                    -            NaN
# ..                                        ...            ...
# 228                      - - de -    -.0
# 229                              - García            NaN
# 230                                  -    -.0
# 231                               Las -    -.0
# 232  AV. 6A. ORIENTE - 18 BARRIO B            NaN
#
#      external_code_text
# 0           -.0
# 1                   NaN
# 2           -.0
# 3           -.0
# ...

# %%
url2=('/content/estruturas_avmx_20240319_185909.csv')

# %%
df2 = pd.read_csv(url2)
df2
# Out:
#         Codigo Estado                      Nome Estado  Codigo Cidade  \
# 0               10006                           Colima         206001
# 1               10006                           Colima         206002
# 2               10006                           Colima         206002
# 3               10006                           Colima         206003
# 4               10006                           Colima         206003
# ...               ...                              ...            ...
# 154019          10030  Veracruz de Ignacio de la Llave         230226
# 154020          10030  Veracruz de Ignacio de la Llave         230226
# 154021          10030  Veracruz de Ignacio de la Llave         230226
# 154022          10030  Veracruz de Ignacio de la Llave         230227
# 154023          10030  Veracruz de Ignacio de la Llave         230227
#
#                              Nome Cidade  Codigo municipio  \
# 0                                Armería         306001001
# ...

# %%
df.loc[df['person_id'] == '7b187a22-f34d-46fc-822e-1e6f5a794e70']
# Out:
# Empty DataFrame
# Columns: [person_id, level, description, external_code, external_code_text]
# Index: []

# %%
df2.loc[df2['Nome municipio'].str.contains('^TUXPAN.*') & df2['Nome colonia'].str.contains('^ LOC.*')]
# Out:
# Empty DataFrame
# Columns: [Codigo Estado, Nome Estado, Codigo Cidade, Nome Cidade, Codigo municipio, Nome municipio, Codigo colonia, Nome colonia, Codigo postal, Zona geografica, Zona comercial, geo_structure_uid, municio_uid, cidade_uid, estado_uid]
# Index: []
